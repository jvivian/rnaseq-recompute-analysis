# %%
from bokeh.charts import Bar, output_file, show

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import numpy as np

# %% [markdown]
# # Classifier Accuracy

# %%
labels = ['RandomForest', 'ExtraForest', 'AdaBoost', 
         'KNeighbor', 'SGDClassifier', 'RBF SVM', 'LinearSVC']
means = [0.840533909584, 0.831152056753, 0.271531854133,
        0.87137831082, 0.870463301741, 0.86520438009, 0.897161759673]
stds = [0.0553764807566, 0.0619894331496, 0.0584754966475,
       0.0553835576314, 0.0644092770492, 0.0637158178524, 0.0637158178524]

# %%
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.08*height,
                '{}'.format(round(float(height), 2)),
                ha='center', va='bottom')

# %%
f, ax = plt.subplots(figsize=(12, 8))
rects = ax.bar(range(len(labels)), means, yerr=stds, tick_label=labels, align='center', color='g', alpha=0.5)
autolabel(rects)
plt.title('Untuned Tissue Classification Accuracy \n Across TCGA and GTEx')
plt.ylabel('Accuracy Means')
